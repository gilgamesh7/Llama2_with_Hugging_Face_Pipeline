# %% [markdown]
# ### IMPORTANT : Read Readme section "Run model locally using Ollama" for setting up the model locally

# %%
! ollama create expense_analyzer_llama3 -f Modelfile
# Out:
# transferring model data
# reading model metadata
# creating system layer
# creating parameters layer
# creating config layer
# using already created layer sha256:00e1317cbf74d901080d7100f57580ba8dd8de57203072dc6f668324ba545f29
# using already created layer sha256:4fa551d4f938f68b8c1e6afa9d28befb70e3f33f75d0753248d530364aeea40f
# using already created layer sha256:8ab4849b038cf0abc5b1c9b8ee1443dca6b93a045c2272180d985126eb40bf6f
# writing layer sha256:aaa285176a6644a02f0f36f1110d8732658803188f36f2f115291fbcf970f9cb
# using already created layer sha256:d02f8eeff855caf58609588ee111469b8b4f8dc81315c278779901e23a25eddb
# writing layer sha256:3d9a7f4ea65e363a90ada992cc6e8bf5a94101cef82fe7b41bb4238ea2d4cb56
# writing manifest
# success

# %%
! ollama list
# Out:
# NAME                          	ID          	SIZE  	MODIFIED
# expense_analyzer_llama3:latest	cbe4d141a6d5	4.7 GB	18 seconds ago
# llama3:latest                 	a6990ed6be41	4.7 GB	10 days ago

# %%
! pip install langchain_community pandas

# %%
! pip freeze > requirements.txt

# %%
from langchain_community.llms import Ollama

# %%
# Test llm
llm = Ollama(model="expense_analyzer_llama3")
llm.invoke("what category does money spent on a dentist fall under?")
# Out:
# 'As a financial assistant, I would categorize money spent on a dentist as "Healthcare" or more specifically, "Medical/Dental Expenses". This category includes any costs related to medical care, including dental procedures, doctor visits, and prescriptions. In QuickBooks, for example, this would likely be classified under the "Healthcare" expense account.'

# %%
# Process credit card bill
import pandas as pd

df = pd.read_csv("4988-xxxx-xxxx-6116_Transactions_2024-01-01_2024-05-08.csv")
df
# Out:
#                     Card Type  Amount  \
# 0    4988-****-****-6568    D    2.90
# 1    4988-****-****-6568    D    5.10
# 2    4988-****-****-6568    D    3.76
# 3    4988-****-****-6568    D  192.91
# 4    4988-****-****-6568    D    7.50
# ..                   ...  ...     ...
# 452  4988-****-****-6568    D   65.28
# 453  4988-****-****-6568    D    3.99
# 454  4988-****-****-6568    D   20.00
# 455  4988-****-****-6568    D    9.30
# 456  4988-****-****-6568    D    9.49
#
#                                       Details TransactionDate ProcessedDate  \
# 0    7 Mart Convenient St   Auckland      Nz       06/05/2024    07/05/2024
# 1    Bean Grinding          Auckland      Nz       05/05/2024    06/05/2024
# 2    Seed Heritage          Milford       Nz       05/05/2024    06/05/2024
# 3    Pak N Save Wairau Road Northshore Ci Nz       04/05/2024    06/05/2024
# 4    Woolworths Nz/Glenfiel Glenfld Mall  Nz       04/05/2024    06/05/2024
# ..                                        ...             ...           ...
# 452  Regatta Bar & Eatery   Takapuna      Nz       30/12/2023    03/01/2024
# 453  Chemist Warehouse      Newmarket     Nz       29/12/2023    03/01/2024
# 454  Punjabi Kitchen        Wairua Valley Nz       29/12/2023    03/01/2024
# 455  Gong Cha Westfield New Auckland      Nz       29/12/2023    03/01/2024
# 456  Kfc Newmarket - 623    Auckland      Nz       29/12/2023    03/01/2024
#
#     ForeignCurrencyAmount ConversionCharge
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3                     NaN              NaN
# 4                     NaN              NaN
# ..                    ...              ...
# 452                   NaN              NaN
# 453                   NaN              NaN
# 454                   NaN              NaN
# 455                   NaN              NaN
# 456                   NaN              NaN
#
# [457 rows x 8 columns]

# %%
# get unique transactions
unique_transactions = df["Details"].unique()
print(unique_transactions)
f"Unique transactions count : {len(unique_transactions)}"
# Out:
# ['7 Mart Convenient St   Auckland      Nz '
#  'Bean Grinding          Auckland      Nz '
#  'Seed Heritage          Milford       Nz '
#  'Pak N Save Wairau Road Northshore Ci Nz '
#  'Woolworths Nz/Glenfiel Glenfld Mall  Nz '
#  'Namaste Indian Superma Auckland      Nz '
#  'Pizza Hutt Glenfield M Auckland      Nz '
#  'Pasta Cuore            Mount Eden    Nz '
#  'Liquorland Glenfield   Auckland      Nz '
#  'Glenfield 7 Day Phar   Auckland      Nz '
#  'Noughts Crosses Cake   Mount Eden    Nz '
#  'Kara Cafe              Auckland      Nz '
#  'Milford Optometrists   Milford       Nz '
#  'Unichem Fred Thomas    Ellerslie     Nz '
#  'Hell Pizza Glenfield   Auckland      Nz '
#  'Mojo Victoria Square   Auckland      Nz '
#  'Southern Cross Health  Auckland      Nz '
#  'Pak N Save Fuel Wairau Wairau Valley Nz '
#  'Chemist Warehouse      Glenfield     Nz '
#  'Eb Games 308           Glenfield     Nz '
#  'Amazon Music Unlimited Sydney South  Au '
#  'Mcdonalds Glenfield    Auckland      Nz '
#  'The Grange             Auckland      Nz '
#  'Movenpick Takapuna     Takapuna      Nz '
#  'Clarence Cafe          Auckland      Nz '
#  'Online       Payment -  Thank You '
#  'Woolworths Nz/277 Broa Newmarket     Nz '
#  'Event Cinemas Nwmkt    Auckland      Nz '
#  'The Brewers Cooperat   Auckland      Nz '
#  'Wendys Constellation D Auckland      Nz '
#  'Burgerburg* Takapuna   Eden Terrace  Nz '
#  'Kiwiyo Takapuna        Auckland      Nz '
#  'Tower Insurance - Eis  093692079     Nz '
#  'Matsu Sushi            Auckland      Nz '
#  'Chemist Warehouse      Albany        Nz '
#  'Gong Cha Westfield Alb Auckland      Nz '
#  'Subway Westfield Alban Auckland      Nz '
#  'Amazon Prime Video Nz  Singapore     Sg '
#  'Wang Food Market Link  Auckland      Nz '
#  'Burger King Sunnybrae  Hillcrest     Nz '
#  'Punjabi Kitchen        Wairua Valley Nz '
#  'Rollers Bakery         Northcote     Nz '
#  'At Hop Auckland        Smales        Nz '
#  'Saravanaa Bhavan       Auckland      Nz '
#  'Apple.Com/Bill         Sydney        Au '
#  'Gong Cha Takapuna      Auckland      Nz '
#  'New World Albany       Albany Nz     Nz '
#  'Life Pharmacy Albany   Albany        Nz '
#  'The Body Shop Albany   Auckland      Nz '
#  'Pandora Albany         Auckland      Nz '
#  'French Rendez-Vous Caf Auckland      Nz '
#  'Hooverfoods            Beach Haven   Nz '
#  'Arlo                   408-638-3750  Ie '
#  'Cancer Society Aklnth  Grafton       Nz '
#  'Toto                   Auckland      Nz '
#  'Microsoft#G044134410   Msbill.Info   Sg '
#  'Scratch Bakers         Auckland      Nz '
#  'Openai                 Httpsopenai.C Ca '
#  'World Vision Recurring 0800800776    Nz '
#  'Silky Otter Ponsonby   Auckland      Nz '
#  'Zambrero Oteha Valley  Auckland      Nz '
#  'Z Northcote            Northcote     Nz '
#  'Digi Imports Albany    Auckland      Nz '
#  'Mitre 10 Mega Glenfiel Glenfield     Nz '
#  'Mcdonalds Wairau Road  Auckland      Nz '
#  'Atomic Coffee Graham S Auckland      Nz '
#  'Subway Spark City      Auckland      Nz '
#  'Woolworths Nz/124 Hobs Hobsonville   Nz '
#  'Finance Charge Rate Changed Today  **  0.00  **'
#  'Tambo Sa Limited       Titirangi     Nz '
#  'Dit                    Birkenhead    Nz '
#  'Typo Glenfield 9735    Glenfield     Nz '
#  'Subway Takapuna        Auckland      Nz '
#  'Rocoto Nz              Auckland      Nz '
#  'Latino Foods           Auckland      Nz '
#  'Delicias Pascal Chil   Auckland      Nz '
#  'Sals Pizza Birkenhead  Birkenhead    Nz '
#  'Nz Transport Agency-Ec Palmerston No Nz '
#  'Victoria Sushi Telecom Auckland Nz   Nz '
#  'The Pumphouse Theatre  Auckland      Nz '
#  "Tommy Gun'S Glenfiel   Auckland      Nz "
#  'Mr Whippy Northshore   Auckland      Nz '
#  'Cotton On Mega 9936    Glenfield     Nz '
#  'Gong Cha Glenfield     Auckland      Nz '
#  'Twl Glenfield          Auckland      Nz '
#  'Glenfield              Auckland      Nz '
#  'Wild Wheat             Auckland      Nz '
#  'Bunnings - 9491        Glenfield     Nz '
#  'Just Cuts Glenfield    Auckland      Nz '
#  'The Tinted Rose        Auckland      Nz '
#  'Microsoft#G041511273   Msbill.Info   Sg '
#  'Order Meal Ltd         Auckland      Nz '
#  'Hello Mister Hardinge  Auckland Cent Nz '
#  'Mecca Maxima Albany    Auckland      Nz '
#  'Kmart Albany           Auckland      Nz '
#  'Parkmate Nz            Auckland      Nz '
#  'Empire Tavern          Auckland      Nz '
#  'Cj Glenfield 223       Auckland      Nz '
#  'Koffee Bar Albany      Auckland      Nz '
#  'Typo Albany 9736       Albany        Nz '
#  'Starbucks Takapuna     Auckland      Nz '
#  'Retrospace Limited     Auckland      Nz '
#  'Kfc Takapuna - 503     Takapuna      Nz '
#  'Www.Hobsonspledge.Nz   Auckland      Nz '
#  'Hesarigrocerywairauval Auckland      Nz '
#  "Sal'S Pizza            Auckland      Nz "
#  'Countdown Glenf/Glenfi Glenfld Mall  Nz '
#  'Heritage Cuisine Of In Auckland      Nz '
#  'The Portland Public Ho Auckland      Nz '
#  'The Warehouse 119      Albany        Nz '
#  'Countdown Takap/Barrys Takapuna      Nz '
#  'Mobie Albany           Auckland      Nz '
#  'Burger Fuel Glenfield  Auckland      Nz '
#  'Fantail & Turtle Ltd   Auckland      Nz '
#  'Downtown Car Park      Auckland      Nz '
#  'Daily Bread Galway St  Auckland      Nz '
#  'Baked At Greenhithe    Auckland      Nz '
#  'Nzqa                   Wellington    Nz '
#  'Microsoft#G039023290   Msbill.Info   Sg '
#  'Patel Brothers Indian  Auckland      Nz '
#  'Top-In-Town Spice City Hillcrest     Nz '
#  'Briscoes Glenfield     Glenfield     Nz '
#  'Rainbows End Theme Par Manukau City  Nz '
#  'Paper Plus Nz Ltd      Manukau       Nz '
#  'The Red Fort           Greenhithe    Nz '
#  'Lotte Duty Free-T1     Singapore     Sg '
#  'Officemax              Auckland      Nz '
#  'Chow Tai Fook Jewelery Singapore 819 Sg '
#  'Farmers Albany Wstfl   Auckland      Nz '
#  'Supershuttle/Custom    Auckland      Nz '
#  'Z Glen Park            Glenfield     Nz '
#  'Four Square Oneroa     Oneroa        Nz '
#  'Burgerburg* Com Bay    Eden Terrace  Nz '
#  'Waiheke Espresso Ltd   Waiheke Islan Nz '
#  'New World Browns Bay   Auckland      Nz '
#  'Subway Browns Bay      Auckland      Nz '
#  'Penguino Ice Cream     Auckland      Nz '
#  'Aa Driver Training     Auckland      Nz '
#  'Typo Queen Street 9727 Auckland      Nz '
#  'Real Groovy            Auckland      Nz '
#  'Starbucks Queen St     Auckland      Nz '
#  'Sg International Hawke Singapore     Sg '
#  'Bird On A Wire         Auckland      Nz '
#  'Menulog                Auckland      Nz '
#  'Akl Council Online     Auckland      Nz '
#  'Auckland Council Conv  Auckland      Nz '
#  'Gong Cha Westfield New Auckland      Nz '
#  "St Pierre'S Newmarke   Auckland      Nz "
#  'Habitat For Humanity   Auckland      Nz '
#  'Thai Thai Takeaways    Auckland      Nz '
#  'Lord Kitchener         Sandringham   Nz '
#  'Cancer Society Wbop    Auckland      Nz '
#  'Lotsa Goodies Albany   Albany        Nz '
#  'Lovisa Albany          Auckland      Nz '
#  'Microsoft#G036662900   Msbill.Info   Sg '
#  'Krispy Kreme Albany    Auckland      Nz '
#  'Edge Cut Color & Beaut Auckland      Nz '
#  'Hollywood Bakery & Caf Auckland      Nz '
#  'Indian Lounge          Mount Eden    Nz '
#  'Bayview Superette      Auckland      Nz '
#  'White Cross Glenfield  Auckland      Nz '
#  'Bridgeway Cinemas      Northcote Pt  Nz '
#  'Clarence Rd Eatery     Auckland      Nz '
#  'Number One Shoes       Albany        Nz '
#  'Coffee Club Albany     Auckland      Nz '
#  'Sen Sushi              Auckland      Nz '
#  'Something And Social   Auckland      Nz '
#  'Something Social       New Zealand   Nz '
#  'Akld Transport Parking Auckland      Nz '
#  'Farmers 1140           Newmarket     Nz '
#  'Alceon Lcs New Zealand Auckland      Nz '
#  'Watercare Online       Remuera       Nz '
#  'Rialto Newmarket       Newmarket     Nz '
#  'New York Grill         Auckland      Nz '
#  'Duck Island Takapuna   Auckland      Nz '
#  'Shivani Mt Roskill     Auckland      Nz '
#  'Lovisa Newmarket       Auckland      Nz '
#  'Regatta Bar & Eatery   Takapuna      Nz '
#  'Chemist Warehouse      Newmarket     Nz '
#  'Kfc Newmarket - 623    Auckland      Nz ']
# 'Unique transactions count : 180'

# %%
# Index List to batch transactions into 30 each
def hop(start, stop, step):
    for i in range(start, stop, step):
        yield i
    
    yield stop

index_list = list(hop(0, len(unique_transactions),30))
index_list
# Out:
# [0, 30, 60, 90, 120, 150, 180]

# %%
def categorize_transactions(transaction_names,llm):
    response = llm.invoke("Can you add an appropriate category to the following expenses. For example: Spotify AB by Adyen - Entertainment, Beta Boulders Ams Amsterdam Nld - Sport, etc.. Categories should be less than 4 words. " + transaction_names)
    response = response.split('\n')

    print(response)

    # Put in dataframe
    categories_df = pd.DataFrame({'Transaction vs category': response})
    categories_df[['Transaction', 'Category']] = categories_df['Transaction vs category'].str.split(' - ', expand=True)
    
    return categories_df

# %%
# initialise categories dataframe
categories_df_all = pd.DataFrame()

# Loop through index list
for i in range(0, len(index_list)-1):
    transaction_names = unique_transactions[index_list[i]:index_list[i+1]]
    transaction_names = '.'.join(transaction_names)

    categories_df = categorize_transactions(transaction_names,llm)
    categories_df_all = pd.concat([categories_df_all, categories_df], ignore_index=True)
# Out:
# ['Here are the categorized expenses:', '', '* 7 Mart Convenient St - Grocery', '* Bean Grinding - Grocery', '* Seed Heritage - Clothing', '* Pak N Save Wairau Road Northshore Ci - Grocery', '* Woolworths Nz/Glenfiel Glenfld Mall - Grocery', '* Namaste Indian Superma - Food', '* Pizza Hutt Glenfield M - Food', '* Pasta Cuore - Food', '* Liquorland Glenfield - Liquor', '* Glenfield 7 Day Phar - Pharmacy', '* Noughts Crosses Cake - Bakery', '* Kara Cafe - Coffee', '* Milford Optometrists - Health', '* Unichem Fred Thomas - Health', '* Hell Pizza Glenfield - Food', '* Mojo Victoria Square - Entertainment', '* Southern Cross Health - Insurance', '* Pak N Save Fuel Wairau Wairau Valley - Gasoline', '* Chemist Warehouse - Pharmacy', '* Eb Games 308 - Entertainment', '* Amazon Music Unlimited - Entertainment', '* Mcdonalds Glenfield - Fast Food', '* The Grange - Home Services', '* Movenpick Takapuna - Accommodation', '* Clarence Cafe - Coffee', '* Online Payment - Miscellaneous', '* Woolworths Nz/277 Broa - Grocery', '* Event Cinemas Nwmkt - Entertainment', '* The Brewers Cooperat - Beer/Wine', '* Wendys Constellation D - Fast Food', '', 'Let me know if you have any questions or need further assistance!']
# ['Here are the categorized expenses:', '', '* Burgerburg Takapuna - Food', '* Kiwiyo Takapuna - Food', '* Tower Insurance - Insurance', '* Matsu Sushi - Food', '* Chemist Warehouse - Pharmacy', '* Gong Cha Westfield Alb - Coffee', '* Subway Westfield Alban - Food', '* Amazon Prime Video - Entertainment', '* Wang Food Market Link - Food', '* Burger King Sunnybrae - Food', '* Punjabi Kitchen - Food', '* Rollers Bakery - Bakery', '* At Hop Auckland - Liquor', '* Saravanaa Bhavan - Food', '* Apple.Com/Bill - Tech', '* Gong Cha Takapuna - Coffee', '* New World Albany - Grocery', '* Life Pharmacy Albany - Pharmacy', '* The Body Shop Albany - Beauty', '* Pandora Albany - Jewelry', '* French Rendez-Vous Caf - Cafe', '* Hooverfoods - Grocery', '* Arlo - Unknown (assuming this is a personal expense)', '* Cancer Society Aklnth - Charity', '* Toto - Unknown (assuming this is a personal expense)', '* Microsoft#G044134410 - Tech', '* Scratch Bakers - Bakery', '* Openai - Unknown (assuming this is a business expense or investment)', '* World Vision Recurring - Charity', '* Silky Otter Ponsonby - Beauty']
# ['Here are the categorized expenses:', '', '* Zambrero Oteha Valley - Food', '* Digi Imports Albany - Electronics', '* Mitre 10 Mega Glenfiel - Hardware', '* McDonalds Wairau Road - Food', '* Atomic Coffee Graham S - Coffee/Drink', '* Subway Spark City - Food', '* Woolworths Nz/124 Hobs - Groceries', '* Tambo Sa Limited - Travel', '* Dit - Miscellaneous', '* Typo Glenfield - Office Supplies', '* Subway Takapuna - Food', '* Rocoto Nz - Food', '* Latino Foods - Food', '* Delicias Pascal Chil - Food', '* Sals Pizza Birkenhead - Food', '* NZ Transport Agency- Ec Palmerston - Transportation', '* Victoria Sushi Telecom Auckland - Food', '* The Pumphouse Theatre - Entertainment', "* Tommy Gun'S Glenfiel - Miscellaneous", '* Mr Whippy Northshore - Snacks', '* Cotton On Mega 9936 - Clothing', '* Gong Cha Glenfield - Coffee/Drink', '* Twl Glenfield - Electronics', '* Glenfield - Utilities/Maintenance', '* Wild Wheat - Food', '* Bunnings 9491 - Hardware', '* Just Cuts Glenfield - Beauty/Haircare', '* The Tinted Rose - Entertainment']
# ['Here are the categorized expenses:', '', '* Microsoft - Software', '* Hello Mister Hardinge - Dining', '* Mecca Maxima Albany - Meal', '* Kmart Albany - Retail', '* Parkmate NZ - Parking', '* Empire Tavern - Drinking', '* Cj Glenfield 223 - Meal', '* Koffee Bar Albany - Beverage', '* Typo Albany 9736 - Retail', '* Starbucks Takapuna - Beverage', '* Retrospace Limited - Entertainment', '* Kfc Takapuna - Food', '* Www.Hobsonspledge.Nz - Donation', '* Hesarigrocerywairauval - Grocery', "* Sal' S Pizza - Dining", '* Countdown Glenf/Glenfi - Grocery', '* Heritage Cuisine Of In - Meal', '* The Portland Public Ho - Entertainment', '* The Warehouse 119 - Retail', '* Countdown Takap/Barrys - Grocery', '* Mobie Albany - Wireless', '* Burger Fuel Glenfield - Food', '* Fantail & Turtle Ltd - Dining', '* Downtown Car Park - Parking', '* Daily Bread Galway St - Bakery', '* Baked At Greenhithe - Bakery', '* Nzqa - Education', '', 'Let me know if you need any further assistance!']
# ['Here are the categorized expenses:', '', '1. Top-In-Town Spice City - Grocery', '2. Briscoes Glenfield - Homeware', '3. Rainbows End Theme Park - Entertainment', '4. Paper Plus - Office Supplies', '5. The Red Fort - Gift Shop', '6. Lotte Duty Free-T1 - Travel', '7. Officemax - Office Supplies', '8. Chow Tai Fook Jewelery - Jewelry', '9. Farmers Albany Wstfl - Grocery', '10. Supershuttle/Custom - Transportation', '11. Z Glen Park - Hardware', '12. Four Square Oneroa - Grocery', '13. Burgerburg* Com Bay - Food', '14. Waiheke Espresso Ltd - Cafe', '15. New World Browns Bay - Grocery', '16. Subway Browns Bay - Food', '17. Penguino Ice Cream - Dessert', '18. Aa Driver Training - Education', '19. Typo Queen Street - Stationery', '20. Real Groovy - Music', '21. Starbucks Queen St - Coffee', "22. Sg International Hawke's - Travel", '23. Bird On A Wire - Gift Shop', '24. Menulog - Food Delivery', '25. Akl Council Online - Government Fee', '26. Auckland Council Conv - Government Fee', '27. Gong Cha Westfield New - Cafe', "28. St Pierre'S Newmarke - Clothing", '29. Habitat For Humanity - Charity', '30. Thai Thai Takeaways - Food', '', "Let me know if you'd like me to make any changes!"]
# ['Here are the categorized expenses:', '', '* Lord Kitchener         Sandringham   Nz  - Charity', '* Cancer Society Wbop    Auckland      Nz  - Charity', '* Lotsa Goodies Albany   Albany        Nz  - Food', '* Lovisa Albany          Auckland      Nz  - Clothing', '* Krispy Kreme Albany    Auckland      Nz  - Food', '* Edge Cut Color & Beaut Auckland      Nz  - Beauty', '* Hollywood Bakery & Caf Auckland      Nz  - Food', '* Indian Lounge          Mount Eden    Nz  - Food', '* Bayview Superette      Auckland      Nz  - Food', '* White Cross Glenfield  Auckland      Nz  - Health', '* Bridgeway Cinemas      Northcote Pt  Nz  - Entertainment', '* Clarence Rd Eatery     Auckland      Nz  - Food', '* Number One Shoes       Albany        Nz  - Clothing', '* Coffee Club Albany     Auckland      Nz  - Food', '* Sen Sushi              Auckland      Nz  - Food', '* Something And Social   Auckland      Nz  - Entertainment', '* Something Social       New Zealand   Nz  - Entertainment', '* Akld Transport Parking Auckland      Nz  - Transportation', '* Farmers 1140           Newmarket     Nz  - Groceries', '* Alceon Lcs New Zealand Auckland      Nz  - Miscellaneous', '* Watercare Online       Remuera       Nz  - Utilities', '* Rialto Newmarket       Newmarket     Nz  - Entertainment', '* New York Grill         Auckland      Nz  - Food', '* Duck Island Takapuna   Auckland      Nz  - Food', '* Shivani Mt Roskill     Auckland      Nz  - Miscellaneous', '* Lovisa Newmarket       Auckland      Nz  - Clothing', '* Regatta Bar & Eatery   Takapuna      Nz  - Food', '* Chemist Warehouse      Newmarket     Nz  - Health', '* Kfc Newmarket  - 623    Auckland      Nz  - Food']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 9
#       6 transaction_names = unique_transactions[index_list[i]:index_list[i+1]]
#       7 transaction_names = '.'.join(transaction_names)
# ----> 9 categories_df = categorize_transactions(transaction_names,llm)
#      10 categories_df_all = pd.concat([categories_df_all, categories_df], ignore_index=True)
#
# Cell In[22], line 9, in categorize_transactions(transaction_names, llm)
#       7 # Put in dataframe
#       8 categories_df = pd.DataFrame({'Transaction vs category': response})
# ----> 9 categories_df[['Transaction', 'Category']] = categories_df['Transaction vs category'].str.split(' - ', expand=True)
#      11 return categories_df
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/Documents/code/Llama2_with_Hugging_Face_Pipeline/venv/lib/python3.12/site-packages/pandas/core/frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/Documents/code/Llama2_with_Hugging_Face_Pipeline/venv/lib/python3.12/site-packages/pandas/core/frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
#    4342         for k1, k2 in zip(key, value.columns):
#    4343             self[k1] = value[k2]
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/Documents/code/Llama2_with_Hugging_Face_Pipeline/venv/lib/python3.12/site-packages/pandas/core/indexers/utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key
